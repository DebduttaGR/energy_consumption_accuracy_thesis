# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pickle as pkl
import math
import requests
import csv
import sklearn
import json
import requests

# %%
def airport_column(airportname,nooftimes) :
    
    airport = []

    for i in range(0,nooftimes):
    
        airport.append(airportname)
        
    return airport

# %%
def dates_column(filename):
    
    f = open(filename,'r')

    unwanted_columns = ['mintempC', 'maxtempF', 'sunHour', 'mintempF', 'maxtempC','totalSnow_cm','astronomy', 'uvIndex']

    data = json.loads(f.read())

    dataframe = pd.DataFrame(data['data']['weather'])

    dataframes = dataframe.drop(unwanted_columns,axis = 1)

    dataframe = pd.DataFrame(dataframes['hourly'])

    dataframes = dataframes.drop(['hourly'],axis = 1)

    dataframes = dataframes.loc[dataframes.index.repeat(24)].reset_index(drop=True)

    dates = dataframes['date']
    
    return dates

# %%
def final_dataframe(filename,noofdays,airport):
    
        f = open(filename,'r')

        unwanted_columns = ['mintempC', 'maxtempF', 'sunHour', 'mintempF', 'maxtempC','totalSnow_cm','astronomy', 'uvIndex']

        unwanted_columns1 = ['FeelsLikeF','winddir16Point','FeelsLikeC','DewPointC','windspeedMiles','HeatIndexF','HeatIndexC','weatherIconUrl','WindGustMiles','weatherDesc','tempC','WindChillC']

        data = json.loads(f.read())

        dataframe = pd.DataFrame(data['data']['weather'])

        dataframes = dataframe.drop(unwanted_columns,axis = 1)

        dataframe = pd.DataFrame(dataframes['hourly'])

        dictionary1 = dataframe.iloc[0]['hourly'][0]

        dataframe1 = pd.DataFrame.from_dict(dictionary1)

        dataframess = pd.DataFrame(columns = dataframe1.columns)

        for j in range(0,noofdays):

            dictionary1 = dataframe.iloc[j]['hourly'][0]

            dataframe1 = pd.DataFrame.from_dict(dictionary1)

            dictionary2 = dataframe.iloc[j]['hourly'][1]

            dataframe2 = pd.DataFrame.from_dict(dictionary2)

            dataframe1 = pd.concat([dataframe1, dataframe2], ignore_index=True)  # Replaced append with concat

            for i in range(2,24) :

                dictionary2 = dataframe.iloc[j]['hourly'][i]

                dataframe2 = pd.DataFrame.from_dict(dictionary2)

                #dataframe1 = dataframe1.append(dataframe2,ignore_index = True)
                dataframe1 = pd.concat([dataframe1, dataframe2], ignore_index=True)#Added this line to replace append

            dataframess = pd.concat([dataframess, dataframe1], ignore_index=True)  # Replaced append with concat

        dataframess = dataframess.drop(unwanted_columns1,axis = 1).drop_duplicates()
        
        nooftimes = noofdays * 24

        dataframess['Airport'] = airport_column(airport,nooftimes)

        dataframess['Date'] = dates_column(filename)

        return dataframess

# %%
def json_to_csv(filename,filename1,noofdays,airport) :
    
    f = open(filename,'r')
    
    data = json.loads(f.read())
    
    dataframe = final_dataframe(filename,noofdays,airport)
    
    dataframe.to_csv(filename1)
    
    return dataframe

# %%
ATL_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-1.csv',31,'ATL')

ATL_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-2.csv',29,'ATL')

ATL_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-3.csv',31,'ATL')

ATL_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-4.csv',30,'ATL')

ATL_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-5.csv',31,'ATL')

ATL_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-6.csv',30,'ATL')

ATL_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-7.csv',31,'ATL')

ATL_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-8.csv',31,'ATL')

ATL_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-9.csv',30,'ATL')

ATL_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-10.csv',31,'ATL')

ATL_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-11.csv',30,'ATL')

ATL_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2016-12.csv',31,'ATL')



ATL_2016_A = pd.concat(
    [ATL_2016_1, ATL_2016_2, ATL_2016_3, ATL_2016_4],
    ignore_index=True
)

ATL_2016_B = pd.concat(
    [ATL_2016_5, ATL_2016_6, ATL_2016_7, ATL_2016_8],
    ignore_index=True
)

ATL_2016_C = pd.concat(
    [ATL_2016_9, ATL_2016_10, ATL_2016_11, ATL_2016_12],
    ignore_index=True
)

ATL_2016 = pd.concat(
    [ATL_2016_A, ATL_2016_B, ATL_2016_C],
    ignore_index=True
)

ATL_2016.to_csv(
    r'/Users/debduttaguharoy/Downloads/Weather/ATL/ATL_2016.csv',
    index=False
)





ATL_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-1.csv',31,'ATL')

ATL_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-2.csv',28,'ATL')

ATL_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-3.csv',31,'ATL')

ATL_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-4.csv',30,'ATL')

ATL_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-5.csv',31,'ATL')

ATL_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-6.csv',30,'ATL')

ATL_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-7.csv',31,'ATL')

ATL_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-8.csv',31,'ATL')

ATL_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-9.csv',30,'ATL')

ATL_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-10.csv',31,'ATL')

ATL_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-11.csv',30,'ATL')

ATL_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/ATL/2017-12.csv',31,'ATL')




ATL_2017_A = pd.concat(
    [ATL_2017_1, ATL_2017_2, ATL_2017_3, ATL_2017_4],
    ignore_index=True
)

ATL_2017_B = pd.concat(
    [ATL_2017_5, ATL_2017_6, ATL_2017_7, ATL_2017_8],
    ignore_index=True
)

ATL_2017_C = pd.concat(
    [ATL_2017_9, ATL_2017_10, ATL_2017_11, ATL_2017_12],
    ignore_index=True
)

ATL_2017 = pd.concat(
    [ATL_2017_A, ATL_2017_B, ATL_2017_C],
    ignore_index=True
)

ATL_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/ATL_2017.csv',index = False)




ATL = pd.concat(
    [ATL_2016, ATL_2017],
    ignore_index=True
)

ATL.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ATL/ATL_2016_2017.csv',index = False)

# %%
CLT_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-1.csv',31,'CLT')

CLT_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-2.csv',29,'CLT')

CLT_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-3.csv',31,'CLT')

CLT_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-4.csv',30,'CLT')

CLT_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-5.csv',31,'CLT')

CLT_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-6.csv',30,'CLT')

CLT_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-7.csv',31,'CLT')

CLT_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-8.csv',31,'CLT')

CLT_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-9.csv',30,'CLT')

CLT_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-10.csv',31,'CLT')

CLT_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-11.csv',30,'CLT')

CLT_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2016-12.csv',31,'CLT')



CLT_2016_A = pd.concat(
    [CLT_2016_1, CLT_2016_2, CLT_2016_3, CLT_2016_4],
    ignore_index=True
)

CLT_2016_B = pd.concat(
    [CLT_2016_5, CLT_2016_6, CLT_2016_7, CLT_2016_8],
    ignore_index=True
)

CLT_2016_C = pd.concat(
    [CLT_2016_9, CLT_2016_10, CLT_2016_11, CLT_2016_12],
    ignore_index=True
)

CLT_2016 = pd.concat(
    [CLT_2016_A, CLT_2016_B, CLT_2016_C],
    ignore_index=True
)

CLT_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/CLT_2016.csv',index = False)





CLT_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-1.csv',31,'CLT')

CLT_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-2.csv',28,'CLT')

CLT_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-3.csv',31,'CLT')

CLT_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-4.csv',30,'CLT')

CLT_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-5.csv',31,'CLT')

CLT_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-6.csv',30,'CLT')

CLT_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-7.csv',31,'CLT')

CLT_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-8.csv',31,'CLT')

CLT_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-9.csv',30,'CLT')

CLT_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-10.csv',31,'CLT')

CLT_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-11.csv',30,'CLT')

CLT_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/CLT/2017-12.csv',31,'CLT')




CLT_2017_A = pd.concat(
    [CLT_2017_1, CLT_2017_2, CLT_2017_3, CLT_2017_4],
    ignore_index=True
)       

CLT_2017_B = pd.concat(
    [CLT_2017_5, CLT_2017_6, CLT_2017_7, CLT_2017_8],
    ignore_index=True
)   

CLT_2017_C = pd.concat(
    [CLT_2017_9, CLT_2017_10, CLT_2017_11, CLT_2017_12],
    ignore_index=True
)

CLT_2017 = pd.concat(
    [CLT_2017_A, CLT_2017_B, CLT_2017_C],
    ignore_index=True
)

CLT_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/CLT_2017.csv',index = False)




CLT = pd.concat(
    [CLT_2016, CLT_2017],
    ignore_index=True
)

CLT.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/CLT/CLT_2016_2017.csv',index = False)

# %%
DEN_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-1.csv',31,'DEN')

DEN_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-2.csv',29,'DEN')

DEN_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-3.csv',31,'DEN')

DEN_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-4.csv',30,'DEN')

DEN_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-5.csv',31,'DEN')

DEN_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-6.csv',30,'DEN')

DEN_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-7.csv',31,'DEN')

DEN_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-8.csv',31,'DEN')

DEN_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-9.csv',30,'DEN')

DEN_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-10.csv',31,'DEN')

DEN_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-11.csv',30,'DEN')

DEN_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2016-12.csv',31,'DEN')



DEN_2016_A = pd.concat(
    [DEN_2016_1, DEN_2016_2, DEN_2016_3, DEN_2016_4],
    ignore_index=True
)

DEN_2016_B = pd.concat(
    [DEN_2016_5, DEN_2016_6, DEN_2016_7, DEN_2016_8],
    ignore_index=True
)

DEN_2016_C = pd.concat(
    [DEN_2016_9, DEN_2016_10, DEN_2016_11, DEN_2016_12],
    ignore_index=True
)

DEN_2016 = pd.concat(
    [DEN_2016_A, DEN_2016_B, DEN_2016_C],
    ignore_index=True
)

DEN_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/DEN_2016.csv',index = False)





DEN_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-1.csv',31,'DEN')

DEN_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-2.csv',28,'DEN')

DEN_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-3.csv',31,'DEN')

DEN_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-4.csv',30,'DEN')

DEN_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-5.csv',31,'DEN')

DEN_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-6.csv',30,'DEN')

DEN_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-7.csv',31,'DEN')

DEN_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-8.csv',31,'DEN')

DEN_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-9.csv',30,'DEN')

DEN_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-10.csv',31,'DEN')

DEN_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-11.csv',30,'DEN')

DEN_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/DEN/2017-12.csv',31,'DEN')




DEN_2017_A = pd.concat(
    [DEN_2017_1, DEN_2017_2, DEN_2017_3, DEN_2017_4],
    ignore_index=True
)   

DEN_2017_B = pd.concat(
    [DEN_2017_5, DEN_2017_6, DEN_2017_7, DEN_2017_8],
    ignore_index=True
)

DEN_2017_C = pd.concat(
    [DEN_2017_9, DEN_2017_10, DEN_2017_11, DEN_2017_12],
    ignore_index=True
)

DEN_2017 = pd.concat(
    [DEN_2017_A, DEN_2017_B, DEN_2017_C],
    ignore_index=True
)

DEN_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/DEN_2017.csv',index = False)




DEN = pd.concat(
    [DEN_2016, DEN_2017],
    ignore_index=True
)   

DEN.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DEN/DEN_2016_2017.csv',index = False)

# %%
DFW_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-1.csv',31,'DFW')

DFW_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-2.csv',29,'DFW')

DFW_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-3.csv',31,'DFW')

DFW_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-4.csv',30,'DFW')

DFW_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-5.csv',31,'DFW')

DFW_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-6.csv',30,'DFW')

DFW_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-7.csv',31,'DFW')

DFW_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-8.csv',31,'DFW')

DFW_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-9.csv',30,'DFW')

DFW_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-10.csv',31,'DFW')

DFW_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-11.csv',30,'DFW')

DFW_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2016-12.csv',31,'DFW')



DFW_2016_A = pd.concat(
    [DFW_2016_1, DFW_2016_2, DFW_2016_3, DFW_2016_4],
    ignore_index=True
)

DFW_2016_B = pd.concat(
    [DFW_2016_5, DFW_2016_6, DFW_2016_7, DFW_2016_8],
    ignore_index=True
)

DFW_2016_C = pd.concat(
    [DFW_2016_9, DFW_2016_10, DFW_2016_11, DFW_2016_12],
    ignore_index=True
)

DFW_2016 = pd.concat(
    [DFW_2016_A, DFW_2016_B, DFW_2016_C],
    ignore_index=True
)

DFW_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/DFW_2016.csv',index = False)





DFW_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-1.csv',31,'DFW')

DFW_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-2.csv',28,'DFW')

DFW_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-3.csv',31,'DFW')

DFW_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-4.csv',30,'DFW')

DFW_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-5.csv',31,'DFW')

DFW_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-6.csv',30,'DFW')

DFW_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-7.csv',31,'DFW')

DFW_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-8.csv',31,'DFW')

DFW_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-9.csv',30,'DFW')

DFW_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-10.csv',31,'DFW')

DFW_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-11.csv',30,'DFW')

DFW_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/DFW/2017-12.csv',31,'DFW')




DFW_2017_A = pd.concat(
    [DFW_2017_1, DFW_2017_2, DFW_2017_3, DFW_2017_4],
    ignore_index=True
)

DFW_2017_B = pd.concat(
    [DFW_2017_5, DFW_2017_6, DFW_2017_7, DFW_2017_8],
    ignore_index=True
)

DFW_2017_C = pd.concat(
    [DFW_2017_9, DFW_2017_10, DFW_2017_11, DFW_2017_12],
    ignore_index=True
)

DFW_2017 = pd.concat(
    [DFW_2017_A, DFW_2017_B, DFW_2017_C],
    ignore_index=True
)

DFW_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/DFW_2017.csv',index = False)




DFW = pd.concat(
    [DFW_2016, DFW_2017],
    ignore_index=True
)

DFW.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/DFW/DFW_2016_2017.csv',index = False)

# %%
EWR_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-1.csv',31,'EWR')

EWR_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-2.csv',29,'EWR')

EWR_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-3.csv',31,'EWR')

EWR_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-4.csv',30,'EWR')

EWR_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-5.csv',31,'EWR')

EWR_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-6.csv',30,'EWR')

EWR_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-7.csv',31,'EWR')

EWR_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-8.csv',31,'EWR')

EWR_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-9.csv',30,'EWR')

EWR_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-10.csv',31,'EWR')

EWR_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-11.csv',30,'EWR')

EWR_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2016-12.csv',31,'EWR')



EWR_2016_A = pd.concat(
    [EWR_2016_1, EWR_2016_2, EWR_2016_3, EWR_2016_4],
    ignore_index=True
)

EWR_2016_B = pd.concat(
    [EWR_2016_5, EWR_2016_6, EWR_2016_7, EWR_2016_8],
    ignore_index=True
)

EWR_2016_C = pd.concat(
    [EWR_2016_9, EWR_2016_10, EWR_2016_11, EWR_2016_12],
    ignore_index=True
)

EWR_2016 = pd.concat(
    [EWR_2016_A, EWR_2016_B, EWR_2016_C],
    ignore_index=True
)

EWR_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/EWR_2016.csv',index = False)





EWR_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-1.csv',31,'EWR')

EWR_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-2.csv',28,'EWR')

EWR_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-3.csv',31,'EWR')

EWR_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-4.csv',30,'EWR')

EWR_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-5.csv',31,'EWR')

EWR_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-6.csv',30,'EWR')

EWR_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-7.csv',31,'EWR')

EWR_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-8.csv',31,'EWR')

EWR_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-9.csv',30,'EWR')

EWR_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-10.csv',31,'EWR')

EWR_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-11.csv',30,'EWR')

EWR_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/EWR/2017-12.csv',31,'EWR')




EWR_2017_A = pd.concat(
    [EWR_2017_1, EWR_2017_2, EWR_2017_3, EWR_2017_4],
    ignore_index=True
)   

EWR_2017_B = pd.concat(
    [EWR_2017_5, EWR_2017_6, EWR_2017_7, EWR_2017_8],
    ignore_index=True
)   

EWR_2017_C = pd.concat(
    [EWR_2017_9, EWR_2017_10, EWR_2017_11, EWR_2017_12],
    ignore_index=True
)   

EWR_2017 = pd.concat(
    [EWR_2017_A, EWR_2017_B, EWR_2017_C],
    ignore_index=True
)

EWR_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/EWR_2017.csv',index = False)




EWR = pd.concat(
    [EWR_2016, EWR_2017],
    ignore_index=True
)

EWR.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/EWR/EWR_2016_2017.csv',index = False)

# %%
IAH_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-1.csv',31,'IAH')

IAH_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-2.csv',29,'IAH')

IAH_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-3.csv',31,'IAH')

IAH_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-4.csv',30,'IAH')

IAH_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-5.csv',31,'IAH')

IAH_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-6.csv',30,'IAH')

IAH_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-7.csv',31,'IAH')

IAH_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-8.csv',31,'IAH')

IAH_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-9.csv',30,'IAH')

IAH_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-10.csv',31,'IAH')

IAH_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-11.csv',30,'IAH')

IAH_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2016-12.csv',31,'IAH')



IAH_2016_A = pd.concat(
    [IAH_2016_1, IAH_2016_2, IAH_2016_3, IAH_2016_4],
    ignore_index=True
)

IAH_2016_B = pd.concat(
    [IAH_2016_5, IAH_2016_6, IAH_2016_7, IAH_2016_8],
    ignore_index=True
)

IAH_2016_C = pd.concat(
    [IAH_2016_9, IAH_2016_10, IAH_2016_11, IAH_2016_12],
    ignore_index=True
)

IAH_2016 = pd.concat(
    [IAH_2016_A, IAH_2016_B, IAH_2016_C],
    ignore_index=True
)

IAH_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/IAH_2016.csv',index = False)





IAH_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-1.csv',31,'IAH')

IAH_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-2.csv',28,'IAH')

IAH_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-3.csv',31,'IAH')

IAH_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-4.csv',30,'IAH')

IAH_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-5.csv',31,'IAH')

IAH_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-6.csv',30,'IAH')

IAH_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-7.csv',31,'IAH')

IAH_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-8.csv',31,'IAH')

IAH_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-9.csv',30,'IAH')

IAH_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-10.csv',31,'IAH')

IAH_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-11.csv',30,'IAH')

IAH_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/IAH/2017-12.csv',31,'IAH')




IAH_2017_A = pd.concat(
    [IAH_2017_1, IAH_2017_2, IAH_2017_3, IAH_2017_4],
    ignore_index=True
)   

IAH_2017_B = pd.concat(
    [IAH_2017_5, IAH_2017_6, IAH_2017_7, IAH_2017_8],
    ignore_index=True
)

IAH_2017_C = pd.concat(
    [IAH_2017_9, IAH_2017_10, IAH_2017_11, IAH_2017_12],
    ignore_index=True
)

IAH_2017 = pd.concat(
    [IAH_2017_A, IAH_2017_B, IAH_2017_C],
    ignore_index=True
)

IAH_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/IAH_2017.csv',index = False)




IAH = pd.concat(
    [IAH_2016, IAH_2017],
    ignore_index=True
)

IAH.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/IAH/IAH_2016_2017.csv',index = False)

# %%
import json5
def dates_column(filename):
    with open(filename, 'r', encoding='utf-8-sig') as f:
        data = json5.loads(f.read())
    # …rest unchanged…

def final_dataframe(filename, noofdays, airport):
    with open(filename, 'r', encoding='utf-8-sig') as f:
        data = json5.loads(f.read())
    # …rest

# %%
JFK_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-1.csv',31,'JFK')

JFK_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-2.csv',29,'JFK')

JFK_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-3.csv',31,'JFK')

JFK_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-4.csv',30,'JFK')

JFK_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-5.csv',31,'JFK')

JFK_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-6.csv',30,'JFK')

JFK_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-7.csv',31,'JFK')

JFK_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-8.csv',31,'JFK')

JFK_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-9.csv',30,'JFK')

JFK_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-10.csv',31,'JFK')

JFK_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-11.csv',30,'JFK')

JFK_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2016-12.csv',31,'JFK')



JFK_2016_A = pd.concat(
    [JFK_2016_1, JFK_2016_2, JFK_2016_3, JFK_2016_4],
    ignore_index=True
)

JFK_2016_B = pd.concat(
    [JFK_2016_5, JFK_2016_6, JFK_2016_7, JFK_2016_8],
    ignore_index=True
)

JFK_2016_C = pd.concat(
    [JFK_2016_9, JFK_2016_10, JFK_2016_11, JFK_2016_12],
    ignore_index=True)  

JFK_2016 = pd.concat(
    [JFK_2016_A, JFK_2016_B, JFK_2016_C],
    ignore_index=True
)

JFK_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/JFK_2016.csv',index = False)





JFK_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-1.csv',31,'JFK')

JFK_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-2.csv',28,'JFK')

JFK_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-3.csv',31,'JFK')

JFK_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-4.csv',30,'JFK')

JFK_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-5.csv',31,'JFK')

JFK_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-6.csv',30,'JFK')

JFK_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-7.csv',31,'JFK')

JFK_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-8.csv',31,'JFK')

JFK_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-9.csv',30,'JFK')

JFK_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-10.csv',31,'JFK')

JFK_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-11.csv',30,'JFK')

JFK_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/JFK/2017-12.csv',31,'JFK')




JFK_2017_A = pd.concat(
    [JFK_2017_1, JFK_2017_2, JFK_2017_3, JFK_2017_4],
    ignore_index=True
)

JFK_2017_B = pd.concat(
    [JFK_2017_5, JFK_2017_6, JFK_2017_7, JFK_2017_8],
    ignore_index=True
)

JFK_2017_C = pd.concat(
    [JFK_2017_9, JFK_2017_10, JFK_2017_11, JFK_2017_12],
    ignore_index=True
)

JFK_2017 = pd.concat(
    [JFK_2017_A, JFK_2017_B, JFK_2017_C],
    ignore_index=True
)
JFK_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/JFK_2017.csv',index = False)




JFK = pd.concat(
    [JFK_2016, JFK_2017],
    ignore_index=True
)

JFK.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/JFK/JFK_2016_2017.csv',index = False)

# %%
LAS_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-1.csv',31,'LAS')

LAS_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-2.csv',29,'LAS')

LAS_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-3.csv',31,'LAS')

LAS_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-4.csv',30,'LAS')

LAS_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-5.csv',31,'LAS')

LAS_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-6.csv',30,'LAS')

LAS_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-7.csv',31,'LAS')

LAS_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-8.csv',31,'LAS')

LAS_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-9.csv',30,'LAS')

LAS_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-10.csv',31,'LAS')

LAS_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-11.csv',30,'LAS')

LAS_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2016-12.csv',31,'LAS')



LAS_2016_A = pd.concat(
    [LAS_2016_1, LAS_2016_2, LAS_2016_3, LAS_2016_4],
    ignore_index=True
)

LAS_2016_B = pd.concat(
    [LAS_2016_5, LAS_2016_6, LAS_2016_7, LAS_2016_8],
    ignore_index=True
)

LAS_2016_C = pd.concat(
    [LAS_2016_9, LAS_2016_10, LAS_2016_11, LAS_2016_12],
    ignore_index=True
)

LAS_2016 = pd.concat(
    [LAS_2016_A, LAS_2016_B, LAS_2016_C],
    ignore_index=True
)

LAS_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/LAS_2016.csv',index = False)





LAS_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-1.csv',31,'LAS')

LAS_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-2.csv',28,'LAS')

LAS_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-3.csv',31,'LAS')

LAS_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-4.csv',30,'LAS')

LAS_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-5.csv',31,'LAS')

LAS_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-6.csv',30,'LAS')

LAS_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-7.csv',31,'LAS')

LAS_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-8.csv',31,'LAS')

LAS_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-9.csv',30,'LAS')

LAS_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-10.csv',31,'LAS')

LAS_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-11.csv',30,'LAS')

LAS_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/LAS/2017-12.csv',31,'LAS')




LAS_2017_A = pd.concat(
    [LAS_2017_1, LAS_2017_2, LAS_2017_3, LAS_2017_4],
    ignore_index=True
)   

LAS_2017_B = pd.concat(
    [LAS_2017_5, LAS_2017_6, LAS_2017_7, LAS_2017_8],
    ignore_index=True
)   

LAS_2017_C = pd.concat(
    [LAS_2017_9, LAS_2017_10, LAS_2017_11, LAS_2017_12],
    ignore_index=True
)   

LAS_2017 = pd.concat(
    [LAS_2017_A, LAS_2017_B, LAS_2017_C],
    ignore_index=True
)

LAS_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/LAS_2017.csv',index = False)




LAS = pd.concat(
    [LAS_2016, LAS_2017],
    ignore_index=True
)

LAS.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAS/LAS_2016_2017.csv',index = False)

# %%
LAX_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-1.csv',31,'LAX')

LAX_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-2.csv',29,'LAX')

LAX_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-3.csv',31,'LAX')

LAX_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-4.csv',30,'LAX')

LAX_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-5.csv',31,'LAX')

LAX_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-6.csv',30,'LAX')

LAX_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-7.csv',31,'LAX')

LAX_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-8.csv',31,'LAX')

LAX_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-9.csv',30,'LAX')

LAX_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-10.csv',31,'LAX')

LAX_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-11.csv',30,'LAX')

LAX_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2016-12.csv',31,'LAX')



LAX_2016_A = pd.concat(
    [LAX_2016_1, LAX_2016_2, LAX_2016_3, LAX_2016_4],
    ignore_index=True
)

LAX_2016_B = pd.concat(
    [LAX_2016_5, LAX_2016_6, LAX_2016_7, LAX_2016_8],
    ignore_index=True
)

LAX_2016_C = pd.concat(
    [LAX_2016_9, LAX_2016_10, LAX_2016_11, LAX_2016_12],
    ignore_index=True
)

LAX_2016 = pd.concat(
    [LAX_2016_A, LAX_2016_B, LAX_2016_C],
    ignore_index=True
)

LAX_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/LAX_2016.csv',index = False)





LAX_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-1.csv',31,'LAX')

LAX_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-2.csv',28,'LAX')

LAX_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-3.csv',31,'LAX')

LAX_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-4.csv',30,'LAX')

LAX_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-5.csv',31,'LAX')

LAX_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-6.csv',30,'LAX')

LAX_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-7.csv',31,'LAX')

LAX_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-8.csv',31,'LAX')

LAX_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-9.csv',30,'LAX')

LAX_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-10.csv',31,'LAX')

LAX_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-11.csv',30,'LAX')

LAX_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/LAX/2017-12.csv',31,'LAX')




LAX_2017_A = pd.concat(
    [LAX_2017_1, LAX_2017_2, LAX_2017_3, LAX_2017_4],
    ignore_index=True
)

LAX_2017_B = pd.concat(
    [LAX_2017_5, LAX_2017_6, LAX_2017_7, LAX_2017_8],
    ignore_index=True
)

LAX_2017_C = pd.concat(
    [LAX_2017_9, LAX_2017_10, LAX_2017_11, LAX_2017_12],
    ignore_index=True
)

LAX_2017 = pd.concat(
    [LAX_2017_A, LAX_2017_B, LAX_2017_C],
    ignore_index=True
)

LAX_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/LAX_2017.csv',index = False)




LAX = pd.concat(
    [LAX_2016, LAX_2017],
    ignore_index=True
)

LAX.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/LAX/LAX_2016_2017.csv',index = False)

# %%
MCO_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-1.csv',31,'MCO')

MCO_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-2.csv',29,'MCO')

MCO_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-3.csv',31,'MCO')

MCO_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-4.csv',30,'MCO')

MCO_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-5.csv',31,'MCO')

MCO_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-6.csv',30,'MCO')

MCO_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-7.csv',31,'MCO')

MCO_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-8.csv',31,'MCO')

MCO_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-9.csv',30,'MCO')

MCO_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-10.csv',31,'MCO')

MCO_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-11.csv',30,'MCO')

MCO_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2016-12.csv',31,'MCO')



MCO_2016_A = pd.concat(
    [MCO_2016_1, MCO_2016_2, MCO_2016_3, MCO_2016_4],
    ignore_index=True
)

MCO_2016_B = pd.concat(
    [MCO_2016_5, MCO_2016_6, MCO_2016_7, MCO_2016_8],
    ignore_index=True
)

MCO_2016_C = pd.concat(
    [MCO_2016_9, MCO_2016_10, MCO_2016_11, MCO_2016_12],
    ignore_index=True
)

MCO_2016 = pd.concat(
    [MCO_2016_A, MCO_2016_B, MCO_2016_C],
    ignore_index=True
)

MCO_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/MCO_2016.csv',index = False)





MCO_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-1.csv',31,'MCO')

MCO_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-2.csv',28,'MCO')

MCO_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-3.csv',31,'MCO')

MCO_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-4.csv',30,'MCO')

MCO_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-5.csv',31,'MCO')

MCO_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-6.csv',30,'MCO')

MCO_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-7.csv',31,'MCO')

MCO_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-8.csv',31,'MCO')

MCO_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-9.csv',30,'MCO')

MCO_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-10.csv',31,'MCO')

MCO_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-11.csv',30,'MCO')

MCO_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/MCO/2017-12.csv',31,'MCO')




MCO_2017_A = pd.concat(
    [MCO_2017_1, MCO_2017_2, MCO_2017_3, MCO_2017_4],
    ignore_index=True
)   

MCO_2017_B = pd.concat(
    [MCO_2017_5, MCO_2017_6, MCO_2017_7, MCO_2017_8],
    ignore_index=True
)

MCO_2017_C = pd.concat(
    [MCO_2017_9, MCO_2017_10, MCO_2017_11, MCO_2017_12],
    ignore_index=True
)

MCO_2017 = pd.concat(
    [MCO_2017_A, MCO_2017_B, MCO_2017_C],
    ignore_index=True
)

MCO_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/MCO_2017.csv',index = False)




MCO = pd.concat(
    [MCO_2016, MCO_2017],
    ignore_index=True
)

MCO.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MCO/MCO_2016_2017.csv',index = False)

# %%
MIA_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-1.csv',31,'MIA')

MIA_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-2.csv',29,'MIA')

MIA_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-3.csv',31,'MIA')

MIA_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-4.csv',30,'MIA')

MIA_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-5.csv',31,'MIA')

MIA_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-6.csv',30,'MIA')

MIA_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-7.csv',31,'MIA')

MIA_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-8.csv',31,'MIA')

MIA_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-9.csv',30,'MIA')

MIA_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-10.csv',31,'MIA')

MIA_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-11.csv',30,'MIA')

MIA_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2016-12.csv',31,'MIA')



MIA_2016_A = pd.concat(
    [MIA_2016_1, MIA_2016_2, MIA_2016_3, MIA_2016_4],
    ignore_index=True
)

MIA_2016_B = pd.concat(
    [MIA_2016_5, MIA_2016_6, MIA_2016_7, MIA_2016_8],
    ignore_index=True
)

MIA_2016_C = pd.concat(
    [MIA_2016_9, MIA_2016_10, MIA_2016_11, MIA_2016_12],
    ignore_index=True
)

MIA_2016 = pd.concat(
    [MIA_2016_A, MIA_2016_B, MIA_2016_C],
    ignore_index=True
)

MIA_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/MIA_2016.csv',index = False)





MIA_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-1.csv',31,'MIA')

MIA_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-2.csv',28,'MIA')

MIA_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-3.csv',31,'MIA')

MIA_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-4.csv',30,'MIA')

MIA_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-5.csv',31,'MIA')

MIA_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-6.csv',30,'MIA')

MIA_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-7.csv',31,'MIA')

MIA_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-8.csv',31,'MIA')

MIA_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-9.csv',30,'MIA')

MIA_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-10.csv',31,'MIA')

MIA_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-11.csv',30,'MIA')

MIA_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/MIA/2017-12.csv',31,'MIA')




MIA_2017_A = pd.concat(
    [MIA_2017_1, MIA_2017_2, MIA_2017_3, MIA_2017_4],
    ignore_index=True
)

MIA_2017_B = pd.concat(
    [MIA_2017_5, MIA_2017_6, MIA_2017_7, MIA_2017_8],
    ignore_index=True
)

MIA_2017_C = pd.concat(
    [MIA_2017_9, MIA_2017_10, MIA_2017_11, MIA_2017_12],
    ignore_index=True
)   

MIA_2017 = pd.concat(
    [MIA_2017_A, MIA_2017_B, MIA_2017_C],
    ignore_index=True
)

MIA_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/MIA_2017.csv',index = False)




MIA = pd.concat(
    [MIA_2016, MIA_2017],
    ignore_index=True
)

MIA.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/MIA/MIA_2016_2017.csv',index = False)

# %%
ORD_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-1.csv',31,'ORD')

ORD_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-2.csv',29,'ORD')

ORD_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-3.csv',31,'ORD')

ORD_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-4.csv',30,'ORD')

ORD_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-5.csv',31,'ORD')

ORD_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-6.csv',30,'ORD')

ORD_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-7.csv',31,'ORD')

ORD_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-8.csv',31,'ORD')

ORD_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-9.csv',30,'ORD')

ORD_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-10.csv',31,'ORD')

ORD_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-11.csv',30,'ORD')

ORD_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2016-12.csv',31,'ORD')



ORD_2016_A = pd.concat(
    [ORD_2016_1, ORD_2016_2, ORD_2016_3, ORD_2016_4],
    ignore_index=True
)

ORD_2016_B = pd.concat(
    [ORD_2016_5, ORD_2016_6, ORD_2016_7, ORD_2016_8],
    ignore_index=True
)

ORD_2016_C = pd.concat(
    [ORD_2016_9, ORD_2016_10, ORD_2016_11, ORD_2016_12],
    ignore_index=True
)

ORD_2016 = pd.concat(
    [ORD_2016_A, ORD_2016_B, ORD_2016_C],
    ignore_index=True
)

ORD_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/ORD_2016.csv',index = False)





ORD_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-1.csv',31,'ORD')

ORD_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-2.csv',28,'ORD')

ORD_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-3.csv',31,'ORD')

ORD_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-4.csv',30,'ORD')

ORD_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-5.csv',31,'ORD')

ORD_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-6.csv',30,'ORD')

ORD_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-7.csv',31,'ORD')

ORD_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-8.csv',31,'ORD')

ORD_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-9.csv',30,'ORD')

ORD_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-10.csv',31,'ORD')

ORD_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-11.csv',30,'ORD')

ORD_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/ORD/2017-12.csv',31,'ORD')




ORD_2017_A = pd.concat(
    [ORD_2017_1, ORD_2017_2, ORD_2017_3, ORD_2017_4],
    ignore_index=True
)

ORD_2017_B = pd.concat(
    [ORD_2017_5, ORD_2017_6, ORD_2017_7, ORD_2017_8],
    ignore_index=True
)

ORD_2017_C = pd.concat(
    [ORD_2017_9, ORD_2017_10, ORD_2017_11, ORD_2017_12],
    ignore_index=True
)   

ORD_2017 = pd.concat(
    [ORD_2017_A, ORD_2017_B, ORD_2017_C],
    ignore_index=True
)

ORD_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/ORD_2017.csv',index = False)




ORD = pd.concat(
    [ORD_2016, ORD_2017],
    ignore_index=True
)

ORD.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/ORD/ORD_2016_2017.csv',index = False)

# %%
PHX_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-1.csv',31,'PHX')

PHX_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-2.csv',29,'PHX')

PHX_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-3.csv',31,'PHX')

PHX_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-4.csv',30,'PHX')

PHX_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-5.csv',31,'PHX')

PHX_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-6.csv',30,'PHX')

PHX_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-7.csv',31,'PHX')

PHX_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-8.csv',31,'PHX')

PHX_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-9.csv',30,'PHX')

PHX_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-10.csv',31,'PHX')

PHX_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-11.csv',30,'PHX')

PHX_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2016-12.csv',31,'PHX')



PHX_2016_A = pd.concat(
    [PHX_2016_1, PHX_2016_2, PHX_2016_3, PHX_2016_4],
    ignore_index=True
)

PHX_2016_B = pd.concat(
    [PHX_2016_5, PHX_2016_6, PHX_2016_7, PHX_2016_8],
    ignore_index=True
)

PHX_2016_C = pd.concat(
    [PHX_2016_9, PHX_2016_10, PHX_2016_11, PHX_2016_12],
    ignore_index=True
)

PHX_2016 = pd.concat(
    [PHX_2016_A, PHX_2016_B, PHX_2016_C],
    ignore_index=True
)

PHX_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/PHX_2016.csv',index = False)





PHX_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-1.csv',31,'PHX')

PHX_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-2.csv',28,'PHX')

PHX_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-3.csv',31,'PHX')

PHX_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-4.csv',30,'PHX')

PHX_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-5.csv',31,'PHX')

PHX_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-6.csv',30,'PHX')

PHX_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-7.csv',31,'PHX')

PHX_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-8.csv',31,'PHX')

PHX_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-9.csv',30,'PHX')

PHX_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-10.csv',31,'PHX')

PHX_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-11.csv',30,'PHX')

PHX_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/PHX/2017-12.csv',31,'PHX')




PHX_2017_A = pd.concat(
    [PHX_2017_1, PHX_2017_2, PHX_2017_3, PHX_2017_4],
    ignore_index=True
)

PHX_2017_B = pd.concat(
    [PHX_2017_5, PHX_2017_6, PHX_2017_7, PHX_2017_8],
    ignore_index=True
)

PHX_2017_C = pd.concat(
    [PHX_2017_9, PHX_2017_10, PHX_2017_11, PHX_2017_12],
    ignore_index=True
)

PHX_2017 = pd.concat(
    [PHX_2017_A, PHX_2017_B, PHX_2017_C],
    ignore_index=True
)

PHX_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/PHX_2017.csv',index = False)




PHX = pd.concat(
    [PHX_2016, PHX_2017],
    ignore_index=True
)

PHX.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/PHX/PHX_2016_2017.csv',index = False)

# %%
SEA_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-1.csv',31,'SEA')

SEA_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-2.csv',29,'SEA')

SEA_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-3.csv',31,'SEA')

SEA_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-4.csv',30,'SEA')

SEA_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-5.csv',31,'SEA')

SEA_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-6.csv',30,'SEA')

SEA_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-7.csv',31,'SEA')

SEA_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-8.csv',31,'SEA')

SEA_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-9.csv',30,'SEA')

SEA_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-10.csv',31,'SEA')

SEA_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-11.csv',30,'SEA')

SEA_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2016-12.csv',31,'SEA')



SEA_2016_A = pd.concat(
    [SEA_2016_1, SEA_2016_2, SEA_2016_3, SEA_2016_4],
    ignore_index=True
)

SEA_2016_B = pd.concat(
    [SEA_2016_5, SEA_2016_6, SEA_2016_7, SEA_2016_8],
    ignore_index=True
)

SEA_2016_C = pd.concat(
    [SEA_2016_9, SEA_2016_10, SEA_2016_11, SEA_2016_12],
    ignore_index=True
)

SEA_2016 = pd.concat(
    [SEA_2016_A, SEA_2016_B, SEA_2016_C],
    ignore_index=True
)

SEA_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/SEA_2016.csv',index = False)





SEA_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-1.csv',31,'SEA')

SEA_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-2.csv',28,'SEA')

SEA_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-3.csv',31,'SEA')

SEA_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-4.csv',30,'SEA')

SEA_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-5.csv',31,'SEA')

SEA_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-6.csv',30,'SEA')

SEA_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-7.csv',31,'SEA')

SEA_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-8.csv',31,'SEA')

SEA_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-9.csv',30,'SEA')

SEA_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-10.csv',31,'SEA')

SEA_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-11.csv',30,'SEA')

SEA_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/SEA/2017-12.csv',31,'SEA')




SEA_2017_A = pd.concat(
    [SEA_2017_1, SEA_2017_2, SEA_2017_3, SEA_2017_4],
    ignore_index=True
)

SEA_2017_B = pd.concat(
    [SEA_2017_5, SEA_2017_6, SEA_2017_7, SEA_2017_8],
    ignore_index=True
)

SEA_2017_C = pd.concat(
    [SEA_2017_9, SEA_2017_10, SEA_2017_11, SEA_2017_12],
    ignore_index=True
)

SEA_2017 = pd.concat(
    [SEA_2017_A, SEA_2017_B, SEA_2017_C],
    ignore_index=True
)

SEA_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/SEA_2017.csv',index = False)




SEA = pd.concat(
    [SEA_2016, SEA_2017],
    ignore_index=True
)

SEA.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SEA/SEA_2016_2017.csv',index = False)

# %%
SFO_2016_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-1.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-1.csv',31,'SFO')

SFO_2016_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-2.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-2.csv',29,'SFO')

SFO_2016_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-3.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-3.csv',31,'SFO')

SFO_2016_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-4.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-4.csv',30,'SFO')

SFO_2016_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-5.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-5.csv',31,'SFO')

SFO_2016_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-6.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-6.csv',30,'SFO')

SFO_2016_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-7.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-7.csv',31,'SFO')

SFO_2016_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-8.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-8.csv',31,'SFO')

SFO_2016_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-9.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-9.csv',30,'SFO')

SFO_2016_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-10.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-10.csv',31,'SFO')

SFO_2016_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-11.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-11.csv',30,'SFO')

SFO_2016_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-12.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2016-12.csv',31,'SFO')



SFO_2016_A = pd.concat(
    [SFO_2016_1, SFO_2016_2, SFO_2016_3, SFO_2016_4],
    ignore_index=True
)

SFO_2016_B = pd.concat(
    [SFO_2016_5, SFO_2016_6, SFO_2016_7, SFO_2016_8],
    ignore_index=True
)

SFO_2016_C = pd.concat(
    [SFO_2016_9, SFO_2016_10, SFO_2016_11, SFO_2016_12],
    ignore_index=True
)

SFO_2016 = pd.concat(
    [SFO_2016_A, SFO_2016_B, SFO_2016_C],
    ignore_index=True
)

SFO_2016.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/SFO_2016.csv',index = False)





SFO_2017_1 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-1.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-1.csv',31,'SFO')

SFO_2017_2 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-2.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-2.csv',28,'SFO')

SFO_2017_3 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-3.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-3.csv',31,'SFO')

SFO_2017_4 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-4.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-4.csv',30,'SFO')

SFO_2017_5 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-5.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-5.csv',31,'SFO')

SFO_2017_6 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-6.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-6.csv',30,'SFO')

SFO_2017_7 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-7.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-7.csv',31,'SFO')

SFO_2017_8 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-8.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-8.csv',31,'SFO')

SFO_2017_9 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-9.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-9.csv',30,'SFO')

SFO_2017_10 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-10.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-10.csv',31,'SFO')

SFO_2017_11 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-11.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-11.csv',30,'SFO')

SFO_2017_12 = json_to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-12.json',r'/Users/debduttaguharoy/Downloads/Weather/SFO/2017-12.csv',31,'SFO')




SFO_2017_A = pd.concat(
    [SFO_2017_1, SFO_2017_2, SFO_2017_3, SFO_2017_4],
    ignore_index=True
)

SFO_2017_B = pd.concat(
    [SFO_2017_5, SFO_2017_6, SFO_2017_7, SFO_2017_8],
    ignore_index=True
)

SFO_2017_C = pd.concat(
    [SFO_2017_9, SFO_2017_10, SFO_2017_11, SFO_2017_12],
    ignore_index=True
)

SFO_2017 = pd.concat(
    [SFO_2017_A, SFO_2017_B, SFO_2017_C],
    ignore_index=True
)

SFO_2017.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/SFO_2017.csv',index = False)




SFO = pd.concat(
    [SFO_2016, SFO_2017],
    ignore_index=True
)

SFO.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/SFO/SFO_2016_2017.csv',index = False)

# %%
weather_data = pd.concat(
    [ATL, CLT, DEN, DFW, EWR, IAH, JFK, LAS, LAX, MCO, MIA, ORD, PHX, SEA, SFO],
    ignore_index=True
)

#Airport_2 = IAH.append(JFK,ignore_index = True).append(LAS,ignore_index = True).append(LAX,ignore_index = True).append(MCO,ignore_index = True)

#Airport_3 = MIA.append(ORD,ignore_index = True).append(PHX,ignore_index = True).append(SEA,ignore_index = True).append(SFO,ignore_index = True)

#weather_data = Airport_1.append(Airport_2,ignore_index = True).append(Airport_3,ignore_index = True)

# %%
weather_data.to_csv(r'/Users/debduttaguharoy/Downloads/Weather/Weather_Data.csv',index = False)
